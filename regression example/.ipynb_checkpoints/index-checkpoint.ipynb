# %% [markdown]
# # Advanced Linear Regression

# %% [markdown]
# We will be using the **Ames housing data** from the Kaggle competition of regression techniques. This dataset is already divided into test and train sets. We will be focusing on using the train data. Now, this dataset has a large number of variables. For the sake of simplicity, we will be focusing on a select few from those. The ```data_description.txt``` file has details of all the features being provided.

# %% [markdown]
# ## Importing the data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

print('- Package Versions:')
print(f'\tMatplotlib = {mpl.__version__}')
print(f'\tPandas = {pd.__version__}')
print(f'\tSeaborn = {sns.__version__}')
# Out:
# - Package Versions:
# 	Matplotlib = 3.3.1
# 	Pandas = 1.1.3
# 	Seaborn = 0.11.0

# %%
cols_to_use = ['YrSold', 'MoSold', 'Fireplaces', 'TotRmsAbvGrd', 'GrLivArea',
          'FullBath', 'YearRemodAdd', 'YearBuilt', 'OverallCond', 
          'OverallQual', 'LotArea', 'SalePrice','BldgType']
df = pd.read_csv("train.csv")
df = df[cols_to_use]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   YrSold        1460 non-null   int64
#  1   MoSold        1460 non-null   int64
#  2   Fireplaces    1460 non-null   int64
#  3   TotRmsAbvGrd  1460 non-null   int64
#  4   GrLivArea     1460 non-null   int64
#  5   FullBath      1460 non-null   int64
#  6   YearRemodAdd  1460 non-null   int64
#  7   YearBuilt     1460 non-null   int64
#  8   OverallCond   1460 non-null   int64
#  9   OverallQual   1460 non-null   int64
#  10  LotArea       1460 non-null   int64
#  11  SalePrice     1460 non-null   int64
#  12  BldgType      1460 non-null   object
# dtypes: int64(12), object(1)
# memory usage: 148.4+ KB

# %% [markdown]
# You will notice that we are only using specific columns from the dataset. This is done purely for managing time better. Feel free to use all the columns if you want. Also when you are working with the test data, ```test.csv``` be sure to apply these same changes to that data. Remember that you will not be provided the ```SalePrice``` for the test data. You can check out the Kaggle competition [here](https://www.kaggle.com/c/house-prices-advanced-regression-techniques). If you submit the predictions, you will get to see the RMSE of your results

# %% [markdown]
# # EDA

# %% [markdown]
# What are some interesting things that we should explore here? Keep in mind that before building a model, we need to first meet some of the assumptions of regression. We also need to identify the continuous and categorical variables and also the correlation between different variables

# %%
# EDA plots
sns.scatterplot(x = "LotArea", y = "SalePrice", data = df)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
sns.boxplot(x = "OverallQual", y = "SalePrice", data = df)
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
df.LotArea.nunique()
# Out:
# 1073

# %%
df.OverallQual.value_counts()
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %%
df.OverallCond.value_counts()
# Out:
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: OverallCond, dtype: int64

# %%
df.BldgType.value_counts()
# Out:
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64

# %%
# heatmap
corr = df.corr()
mask = np.triu(corr)
plt.figure(figsize=(12,10))
sns.heatmap(corr, mask = mask, annot = True, cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
# Make lists of variables we want to use. Its a good idea to make separate lists
# for the continuous and categorical variables
conts = []
cat = []
for col in df.columns:
    if df[col].nunique() < 20:
        cat.append(col)
    else:
        conts.append(col)

# %%
conts
# Out:
# ['GrLivArea', 'YearRemodAdd', 'YearBuilt', 'LotArea', 'SalePrice']

# %%
cat
# Out:
# ['YrSold',
#  'MoSold',
#  'Fireplaces',
#  'TotRmsAbvGrd',
#  'FullBath',
#  'OverallCond',
#  'OverallQual',
#  'BldgType']

# %%
df.loc[:, cat]
# Out:
#       YrSold  MoSold  Fireplaces  TotRmsAbvGrd  FullBath  OverallCond  \
# 0       2008       2           0             8         2            5
# 1       2007       5           1             6         2            8
# 2       2008       9           1             6         2            5
# 3       2006       2           1             7         1            5
# 4       2008      12           1             9         2            5
# ...      ...     ...         ...           ...       ...          ...
# 1455    2007       8           1             7         2            5
# 1456    2010       2           2             7         2            6
# 1457    2010       5           2             9         2            9
# 1458    2010       4           0             5         1            6
# 1459    2008       6           0             6         1            6
#
#       OverallQual BldgType
# 0               7     1Fam
# 1               6     1Fam
# 2               7     1Fam
# 3               7     1Fam
# 4               8     1Fam
# ...           ...      ...
# 1455            6     1Fam
# 1456            6     1Fam
# 1457            7     1Fam
# 1458            5     1Fam
# 1459            5     1Fam
#
# [1460 rows x 8 columns]

# %% [markdown]
# ## Identifying the variables we will be using and their types

# %% [markdown]
# Lets make some quick plots to try and identify the variables we will be using. To start with, we want to make a baseline model. Baseline models are defined as simple models that have decent results. They are not necessarily the best models, but they are easy to build and interpret

# %%
# identify the top 3 variables and make a new df with them
df_baseline = df.loc[:, ['SalePrice', 'OverallQual', 'GrLivArea']]
df_baseline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SalePrice    1460 non-null   int64
#  1   OverallQual  1460 non-null   int64
#  2   GrLivArea    1460 non-null   int64
# dtypes: int64(3)
# memory usage: 34.3 KB

# %% [markdown]
# # Modeling

# %% [markdown]
# The idea behind modeling when using linear regression is to iteratively address issues in the previous models and build better models. There are various techniques available to us to improve our results. We will cover them briefly here.

# %% [markdown]
# ## Linear Regression Models

# %% [markdown]
# ### Baseline Model

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
df_baseline
# Out:
#       SalePrice  OverallQual  GrLivArea
# 0        208500            7       1710
# 1        181500            6       1262
# 2        223500            7       1786
# 3        140000            7       1717
# 4        250000            8       2198
# ...         ...          ...        ...
# 1455     175000            6       1647
# 1456     210000            6       2073
# 1457     266500            7       2340
# 1458     142125            5       1078
# 1459     147500            5       1256
#
# [1460 rows x 3 columns]

# %% [markdown]
# Lets first build the baseline model. We will use the 3 variables we selected above and build the baseline model.

# %%
# build the model and print the summary
y = df_baseline['SalePrice']
X = df_baseline.drop(['SalePrice'], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, \
                                                    random_state = 42)

# %%
model_1 = sm.OLS(y_train, sm.add_constant(X_train)).fit()
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.699
# Method:                 Least Squares   F-statistic:                     1274.
# Date:                Thu, 19 Jan 2023   Prob (F-statistic):          3.06e-286
# Time:                        15:16:10   Log-Likelihood:                -13228.
# No. Observations:                1095   AIC:                         2.646e+04
# Df Residuals:                    1092   BIC:                         2.648e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.008e+05   5954.490    -16.922      0.000   -1.12e+05   -8.91e+04
# OverallQual  3.292e+04   1163.778     28.288      0.000    3.06e+04    3.52e+04
# GrLivArea      52.6894      3.017     17.464      0.000      46.770      58.609
# ==============================================================================
# Omnibus:                      218.242   Durbin-Watson:                   2.105
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5569.232
# Skew:                           0.148   Prob(JB):                         0.00
# Kurtosis:                      14.044   Cond. No.                     7.55e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.55e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Lets identify interesting things from the summary. List three observations below. Also make sure you interpret at least one coefficient.

# %% [markdown]
# ### Model diagnostics
#
# Determine how this model performs on the assumptions of normality of residuals and homoscedasticity by using the correct plots.

# %%
# model validation
sm.qqplot(model_1.resid, fit = True, line = '45')

# %%
sns.histplot(model_1.resid)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
y_pred_train = model_1.predict(sm.add_constant(X_train))
y_pred_test = model_1.predict(sm.add_constant(X_test))

# %%
print("Error Metrics")
print("Training Errors")
print("Train MAE:", mean_absolute_error(y_train, y_pred_train))
print("Train RMSE:", mean_squared_error(y_train, y_pred_train, squared=False))
print("-------------------------")
print("Test MAE:", mean_absolute_error(y_test, y_pred_test))
print("Test RMSE:", mean_squared_error(y_test, y_pred_test, squared=False))
# Out:
# Error Metrics
# Training Errors
# Train MAE: 28993.121758162935
# Train RMSE: 42676.20981245057
# -------------------------
# Test MAE: 27568.444005193352
# Test RMSE: 41970.1828793952

# %% [markdown]
# List out your observations from the plots

# %% [markdown]
# ### Model 2 - Including the categorical variables

# %% [markdown]
# Now, lets try including the categorical variables and make sure we are dealing with them correctly. Remember that there are 2 ways of dealing with categorical variables - label encoding and one hot encoding
#
# **Label encoding**- Label Encoding refers to converting the labels into a numeric form so as to convert them into the machine-readable form. One big issue in this technique is this may lead to the generation of priority issues in the training of data sets. A label with a high value may be considered to have high priority than a label having a lower value.
#
# **One hot encoding**- This is where the categorical variable is removed and a new binary variable is added for each unique integer value. The binary variables are often called “dummy variables”
#
# Lets decide which technique works here and do this for the ```BldgType``` variable

# %%
# deal with the BldgType variable
# bldg_dummies = pd.get_dummies(df['BldgType'], prefix="bldg_type")
# bldg_dummies.drop(columns = ['bldg_type_2fmCon'], inplace = True)

# %%
X = pd.concat([X, df['BldgType'], df['FullBath']], axis = 1)
y = df['SalePrice']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, \
                                                    random_state = 42)

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(handle_unknown='error', drop='first')

# %%
transformed = ohe.fit_transform(X_train['BldgType'].values.reshape(-1,1)).toarray()
ohe_df = pd.DataFrame(transformed, columns = ohe.get_feature_names())
X_train = X_train.reset_index(drop = True)
X_train = pd.concat([X_train, ohe_df], axis = 1).drop(['BldgType'], axis = 1)

# %%
transformed = ohe.transform(X_test['BldgType'].values.reshape(-1,1)).toarray()
ohe_df = pd.DataFrame(transformed, columns = ohe.get_feature_names())
X_test = X_test.reset_index(drop = True)
X_test = pd.concat([X_test, ohe_df], axis = 1).drop(['BldgType'], axis = 1)

# %%
y_train.reset_index(drop = True, inplace=True)
y_test.reset_index(drop = True, inplace=True)

# %% [markdown]
# Lets now include this variable in our model and see how things change

# %%
# build the model

model_2 = sm.OLS(y_train, sm.add_constant(X_train)).fit()
model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.712
# Model:                            OLS   Adj. R-squared:                  0.710
# Method:                 Least Squares   F-statistic:                     384.4
# Date:                Thu, 19 Jan 2023   Prob (F-statistic):          8.02e-289
# Time:                        15:16:11   Log-Likelihood:                -13205.
# No. Observations:                1095   AIC:                         2.643e+04
# Df Residuals:                    1087   BIC:                         2.647e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        -9.66e+04   6050.006    -15.967      0.000   -1.08e+05   -8.47e+04
# OverallQual  3.188e+04   1274.684     25.012      0.000    2.94e+04    3.44e+04
# GrLivArea      46.8850      3.451     13.584      0.000      40.113      53.657
# FullBath     9175.9441   3159.139      2.905      0.004    2977.243    1.54e+04
# x0_2fmCon   -2.192e+04   8336.010     -2.630      0.009   -3.83e+04   -5564.845
# x0_Duplex   -2.129e+04   7315.759     -2.910      0.004   -3.56e+04   -6933.128
# x0_Twnhs    -3.852e+04   7614.642     -5.059      0.000   -5.35e+04   -2.36e+04
# x0_TwnhsE   -1.318e+04   4987.186     -2.642      0.008    -2.3e+04   -3392.986
# ==============================================================================
# Omnibus:                      231.322   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5435.529
# Skew:                           0.326   Prob(JB):                         0.00
# Kurtosis:                      13.895   Cond. No.                     1.10e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# model diagnostics
sm.qqplot(model_2.resid, fit = True, line = '45')

# %%
sns.histplot(model_2.resid)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
y_pred_train = model_2.predict(sm.add_constant(X_train))
y_pred_test = model_2.predict(sm.add_constant(X_test))

# %%
print("Error Metrics")
print("Training Errors")
print("Train MAE:", mean_absolute_error(y_train, y_pred_train))
print("Train RMSE:", mean_squared_error(y_train, y_pred_train, squared=False))
print("-------------------------")
print("Test MAE:", mean_absolute_error(y_test, y_pred_test))
print("Test RMSE:", mean_squared_error(y_test, y_pred_test, squared=False))
# Out:
# Error Metrics
# Training Errors
# Train MAE: 28167.385089459403
# Train RMSE: 41795.79700200322
# -------------------------
# Test MAE: 27820.749078228604
# Test RMSE: 41923.52997043786

# %% [markdown]
# ### Model 3 - Transformations of data

# %% [markdown]
# Log transformation is a data transformation method in which it replaces each variable x with a log(x). In other words, the log transformation reduces or removes the skewness of our original data. The log transformation can be used to make highly skewed distributions less skewed.

# %%
# lets log transform the dependent variable
log_y_train = np.log(y_train)
X_train['GrLivArea'] = np.log(X_train['GrLivArea'])

# %%
log_y_test = np.log(y_test)
X_test['GrLivArea'] = np.log(X_test['GrLivArea'])

# %%
# build a new model with the log transformed target
model_3 = sm.OLS(log_y_train, sm.add_constant(X_train)).fit()
model_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.754
# Method:                 Least Squares   F-statistic:                     480.8
# Date:                Thu, 19 Jan 2023   Prob (F-statistic):               0.00
# Time:                        15:16:11   Log-Likelihood:                 240.10
# No. Observations:                1095   AIC:                            -464.2
# Df Residuals:                    1087   BIC:                            -424.2
# Df Model:                           7
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           8.2089      0.170     48.380      0.000       7.876       8.542
# OverallQual     0.1608      0.006     26.764      0.000       0.149       0.173
# GrLivArea       0.3783      0.027     14.191      0.000       0.326       0.431
# FullBath        0.0635      0.015      4.257      0.000       0.034       0.093
# x0_2fmCon      -0.1482      0.039     -3.824      0.000      -0.224      -0.072
# x0_Duplex      -0.1232      0.034     -3.621      0.000      -0.190      -0.056
# x0_Twnhs       -0.2218      0.035     -6.263      0.000      -0.291      -0.152
# x0_TwnhsE      -0.0430      0.023     -1.856      0.064      -0.088       0.002
# ==============================================================================
# Omnibus:                      225.240   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              842.708
# Skew:                          -0.949   Prob(JB):                    1.02e-183
# Kurtosis:                       6.856   Cond. No.                         285.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# model diagnostics
sm.qqplot(model_3.resid, fit = True, line = '45')

# %%
sns.histplot(model_3.resid)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
y_pred_train = model_3.predict(sm.add_constant(X_train))
y_pred_test = model_3.predict(sm.add_constant(X_test))

# %%
y_pred_train = np.exp(y_pred_train)
y_pred_test = np.exp(y_pred_test)

# %%
print("Error Metrics")
print("Training Errors")
print("Train MAE:", mean_absolute_error(y_train, y_pred_train))
print("Train RMSE:", mean_squared_error(y_train, y_pred_train, squared=False))
print("-------------------------")
print("Test MAE:", mean_absolute_error(y_test, y_pred_test))
print("Test RMSE:", mean_squared_error(y_test, y_pred_test, squared=False))
# Out:
# Error Metrics
# Training Errors
# Train MAE: 25269.666734819188
# Train RMSE: 39211.9883508348
# -------------------------
# Test MAE: 24718.06694388644
# Test RMSE: 38000.918624767524

# %% [markdown]
# ### Checking Homoscedasticity

# %%
sns.scatterplot(model_3.predict(sm.add_constant(X_test)), model_3.resid)
plt.axhline(0, color = 'red')
# Out:
# /Users/fisadmin/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor 

model_4 = DecisionTreeRegressor(random_state = 42)

# %%
model_4.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
model_4.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': 'deprecated',
#  'random_state': 42,
#  'splitter': 'best'}

# %%
model_4.get_depth()
# Out:
# 23

# %%
print("Train R squared:", model_4.score(X_train, y_train))
print("Test R squared:", model_4.score(X_test, y_test))
# Out:
# Train R squared: 0.988067919973317
# Test R squared: 0.71367854325218

# %%
y_pred_train = model_4.predict(X_train)
y_pred_test = model_4.predict(X_test)

# %%
print("Error Metrics")
print("Training Errors")
print("Train MAE:", mean_absolute_error(y_train, y_pred_train))
print("Train RMSE:", mean_squared_error(y_train, y_pred_train, squared=False))
print("-------------------------")
print("Test MAE:", mean_absolute_error(y_test, y_pred_test))
print("Test RMSE:", mean_squared_error(y_test, y_pred_test, squared=False))
# Out:
# Error Metrics
# Training Errors
# Train MAE: 2289.8486301369862
# Train RMSE: 8511.461048283423
# -------------------------
# Test MAE: 30195.17671232877
# Test RMSE: 44785.82691917706

# %%
feat_importances = pd.Series(model_4.feature_importances_, index=X_train.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %% [markdown]
# ### Gridsearch on the decision tree

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
              'max_depth':[3,6,9,12],
              'min_samples_leaf': [5,10]
             }

# %%
model_5 = DecisionTreeRegressor(random_state = 42)
grid_dt = GridSearchCV(model_5, param_grid, cv = 5, scoring='neg_mean_squared_error')
grid_dt.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42),
#              param_grid={'max_depth': [3, 6, 9, 12],
#                          'min_samples_leaf': [5, 10]},
#              scoring='neg_mean_squared_error')

# %%
grid_dt.best_params_
# Out:
# {'max_depth': 6, 'min_samples_leaf': 10}

# %%
y_pred_train = grid_dt.predict(X_train)
y_pred_test = grid_dt.predict(X_test)

# %%
print("Error Metrics")
print("Training Errors")
print("Train MAE:", mean_absolute_error(y_train, y_pred_train))
print("Train RMSE:", mean_squared_error(y_train, y_pred_train, squared=False))
print("-------------------------")
print("Test MAE:", mean_absolute_error(y_test, y_pred_test))
print("Test RMSE:", mean_squared_error(y_test, y_pred_test, squared=False))
# Out:
# Error Metrics
# Training Errors
# Train MAE: 24413.54636380605
# Train RMSE: 35992.54487591038
# -------------------------
# Test MAE: 25328.670177916865
# Test RMSE: 38551.3547301432
